# %% [markdown]
# ## Loading data

# %%
import joblib as jb

# loading training data: ADNI
X_train, y_train = jb.load("D:/Projetos Pessoais/ADPrediction/paper_code_and_files/saved_files/training_data.pkl")

# loading testing data: Centro de Diagnóstico por Imagem (CDI)
X_test, y_test = jb.load("D:/Projetos Pessoais/ADPrediction/paper_code_and_files/saved_files/testing_data.pkl")

# %%
print("X_train.shape:", X_train.shape)
print("X_test.shape:", X_test.shape)
# Out:
# X_train.shape: (200, 176664)
# X_test.shape: (192, 176664)

# %% [markdown]
# ## Training and tuning hyperparameters of the model

# %%
from skopt.space import Real, Categorical
from skopt import BayesSearchCV
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression

# param_distribution for BayesSearch
param_distributions = {"LR__penalty": Categorical(["l1", "l2"]),
                      "LR__C": Real(1e-1, 1e3, prior="log-uniform"),
                      "PCA__n_components": Real(.5, .95)}

# pipeline with PCA and Logistic Regression
pipe = Pipeline([("PCA", PCA(whiten = True)),
                 ("LR", LogisticRegression(solver = "saga", n_jobs = -1, max_iter = 5000))])

# fitting GridSearch and saving the results
bs = BayesSearchCV(pipe, param_distributions, scoring = "f1", n_iter=50, verbose=10)
bs.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=0.146465666852577, LR__penalty=l2, PCA__n_components=0.7149920106857409
# [CV 1/5; 1/1] END LR__C=0.146465666852577, LR__penalty=l2, PCA__n_components=0.7149920106857409;, score=0.919 total time=  15.5s
# [CV 2/5; 1/1] START LR__C=0.146465666852577, LR__penalty=l2, PCA__n_components=0.7149920106857409
# [CV 2/5; 1/1] END LR__C=0.146465666852577, LR__penalty=l2, PCA__n_components=0.7149920106857409;, score=0.833 total time=  15.4s
# [CV 3/5; 1/1] START LR__C=0.146465666852577, LR__penalty=l2, PCA__n_components=0.7149920106857409
# [CV 3/5; 1/1] END LR__C=0.146465666852577, LR__penalty=l2, PCA__n_components=0.7149920106857409;, score=0.778 total time=  12.9s
# [CV 4/5; 1/1] START LR__C=0.146465666852577, LR__penalty=l2, PCA__n_components=0.7149920106857409
# [CV 4/5; 1/1] END LR__C=0.146465666852577, LR__penalty=l2, PCA__n_components=0.7149920106857409;, score=0.821 total time=  13.5s
# [CV 5/5; 1/1] START LR__C=0.146465666852577, LR__penalty=l2, PCA__n_components=0.7149920106857409
# [CV 5/5; 1/1] END LR__C=0.146465666852577, LR__penalty=l2, PCA__n_components=0.7149920106857409;, score=0.923 total time=  11.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=38.75415985863727, LR__penalty=l2, PCA__n_components=0.7266703234298693
# [CV 1/5; 1/1] END LR__C=38.75415985863727, LR__penalty=l2, PCA__n_components=0.7266703234298693;, score=0.947 total time=  12.9s
# [CV 2/5; 1/1] START LR__C=38.75415985863727, LR__penalty=l2, PCA__n_components=0.7266703234298693
# [CV 2/5; 1/1] END LR__C=38.75415985863727, LR__penalty=l2, PCA__n_components=0.7266703234298693;, score=0.895 total time=  12.9s
# [CV 3/5; 1/1] START LR__C=38.75415985863727, LR__penalty=l2, PCA__n_components=0.7266703234298693
# [CV 3/5; 1/1] END LR__C=38.75415985863727, LR__penalty=l2, PCA__n_components=0.7266703234298693;, score=0.927 total time=  12.1s
# [CV 4/5; 1/1] START LR__C=38.75415985863727, LR__penalty=l2, PCA__n_components=0.7266703234298693
# [CV 4/5; 1/1] END LR__C=38.75415985863727, LR__penalty=l2, PCA__n_components=0.7266703234298693;, score=0.762 total time=  12.3s
# [CV 5/5; 1/1] START LR__C=38.75415985863727, LR__penalty=l2, PCA__n_components=0.7266703234298693
# [CV 5/5; 1/1] END LR__C=38.75415985863727, LR__penalty=l2, PCA__n_components=0.7266703234298693;, score=0.974 total time=  12.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=164.85806002703555, LR__penalty=l2, PCA__n_components=0.8971450737780144
# [CV 1/5; 1/1] END LR__C=164.85806002703555, LR__penalty=l2, PCA__n_components=0.8971450737780144;, score=0.900 total time=  12.4s
# [CV 2/5; 1/1] START LR__C=164.85806002703555, LR__penalty=l2, PCA__n_components=0.8971450737780144
# [CV 2/5; 1/1] END LR__C=164.85806002703555, LR__penalty=l2, PCA__n_components=0.8971450737780144;, score=0.811 total time=  12.1s
# [CV 3/5; 1/1] START LR__C=164.85806002703555, LR__penalty=l2, PCA__n_components=0.8971450737780144
# [CV 3/5; 1/1] END LR__C=164.85806002703555, LR__penalty=l2, PCA__n_components=0.8971450737780144;, score=0.889 total time=  12.6s
# [CV 4/5; 1/1] START LR__C=164.85806002703555, LR__penalty=l2, PCA__n_components=0.8971450737780144
# [CV 4/5; 1/1] END LR__C=164.85806002703555, LR__penalty=l2, PCA__n_components=0.8971450737780144;, score=0.864 total time=  12.6s
# [CV 5/5; 1/1] START LR__C=164.85806002703555, LR__penalty=l2, PCA__n_components=0.8971450737780144
# [CV 5/5; 1/1] END LR__C=164.85806002703555, LR__penalty=l2, PCA__n_components=0.8971450737780144;, score=0.930 total time=  11.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=0.27099210821145037, LR__penalty=l1, PCA__n_components=0.9360214645999072
# [CV 1/5; 1/1] END LR__C=0.27099210821145037, LR__penalty=l1, PCA__n_components=0.9360214645999072;, score=0.947 total time=  11.9s
# [CV 2/5; 1/1] START LR__C=0.27099210821145037, LR__penalty=l1, PCA__n_components=0.9360214645999072
# [CV 2/5; 1/1] END LR__C=0.27099210821145037, LR__penalty=l1, PCA__n_components=0.9360214645999072;, score=0.950 total time=  11.5s
# [CV 3/5; 1/1] START LR__C=0.27099210821145037, LR__penalty=l1, PCA__n_components=0.9360214645999072
# [CV 3/5; 1/1] END LR__C=0.27099210821145037, LR__penalty=l1, PCA__n_components=0.9360214645999072;, score=0.833 total time=  21.2s
# [CV 4/5; 1/1] START LR__C=0.27099210821145037, LR__penalty=l1, PCA__n_components=0.9360214645999072
# [CV 4/5; 1/1] END LR__C=0.27099210821145037, LR__penalty=l1, PCA__n_components=0.9360214645999072;, score=0.857 total time=  11.8s
# [CV 5/5; 1/1] START LR__C=0.27099210821145037, LR__penalty=l1, PCA__n_components=0.9360214645999072
# [CV 5/5; 1/1] END LR__C=0.27099210821145037, LR__penalty=l1, PCA__n_components=0.9360214645999072;, score=1.000 total time=  11.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=267.49331322720354, LR__penalty=l1, PCA__n_components=0.8527315401935565
# [CV 1/5; 1/1] END LR__C=267.49331322720354, LR__penalty=l1, PCA__n_components=0.8527315401935565;, score=0.900 total time=  12.3s
# [CV 2/5; 1/1] START LR__C=267.49331322720354, LR__penalty=l1, PCA__n_components=0.8527315401935565
# [CV 2/5; 1/1] END LR__C=267.49331322720354, LR__penalty=l1, PCA__n_components=0.8527315401935565;, score=0.769 total time=  12.0s
# [CV 3/5; 1/1] START LR__C=267.49331322720354, LR__penalty=l1, PCA__n_components=0.8527315401935565
# [CV 3/5; 1/1] END LR__C=267.49331322720354, LR__penalty=l1, PCA__n_components=0.8527315401935565;, score=0.837 total time=  12.1s
# [CV 4/5; 1/1] START LR__C=267.49331322720354, LR__penalty=l1, PCA__n_components=0.8527315401935565
# [CV 4/5; 1/1] END LR__C=267.49331322720354, LR__penalty=l1, PCA__n_components=0.8527315401935565;, score=0.857 total time=  11.9s
# [CV 5/5; 1/1] START LR__C=267.49331322720354, LR__penalty=l1, PCA__n_components=0.8527315401935565
# [CV 5/5; 1/1] END LR__C=267.49331322720354, LR__penalty=l1, PCA__n_components=0.8527315401935565;, score=0.930 total time=  12.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=323.35219564093853, LR__penalty=l1, PCA__n_components=0.8376952365171728
# [CV 1/5; 1/1] END LR__C=323.35219564093853, LR__penalty=l1, PCA__n_components=0.8376952365171728;, score=0.872 total time=  12.0s
# [CV 2/5; 1/1] START LR__C=323.35219564093853, LR__penalty=l1, PCA__n_components=0.8376952365171728
# [CV 2/5; 1/1] END LR__C=323.35219564093853, LR__penalty=l1, PCA__n_components=0.8376952365171728;, score=0.829 total time=  11.8s
# [CV 3/5; 1/1] START LR__C=323.35219564093853, LR__penalty=l1, PCA__n_components=0.8376952365171728
# [CV 3/5; 1/1] END LR__C=323.35219564093853, LR__penalty=l1, PCA__n_components=0.8376952365171728;, score=0.857 total time=  13.4s
# [CV 4/5; 1/1] START LR__C=323.35219564093853, LR__penalty=l1, PCA__n_components=0.8376952365171728
# [CV 4/5; 1/1] END LR__C=323.35219564093853, LR__penalty=l1, PCA__n_components=0.8376952365171728;, score=0.810 total time=  11.9s
# [CV 5/5; 1/1] START LR__C=323.35219564093853, LR__penalty=l1, PCA__n_components=0.8376952365171728
# [CV 5/5; 1/1] END LR__C=323.35219564093853, LR__penalty=l1, PCA__n_components=0.8376952365171728;, score=0.952 total time=  12.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=182.78053240289583, LR__penalty=l2, PCA__n_components=0.5026985989439481
# [CV 1/5; 1/1] END LR__C=182.78053240289583, LR__penalty=l2, PCA__n_components=0.5026985989439481;, score=0.919 total time=  12.2s
# [CV 2/5; 1/1] START LR__C=182.78053240289583, LR__penalty=l2, PCA__n_components=0.5026985989439481
# [CV 2/5; 1/1] END LR__C=182.78053240289583, LR__penalty=l2, PCA__n_components=0.5026985989439481;, score=0.800 total time=  12.7s
# [CV 3/5; 1/1] START LR__C=182.78053240289583, LR__penalty=l2, PCA__n_components=0.5026985989439481
# [CV 3/5; 1/1] END LR__C=182.78053240289583, LR__penalty=l2, PCA__n_components=0.5026985989439481;, score=0.757 total time=  11.9s
# [CV 4/5; 1/1] START LR__C=182.78053240289583, LR__penalty=l2, PCA__n_components=0.5026985989439481
# [CV 4/5; 1/1] END LR__C=182.78053240289583, LR__penalty=l2, PCA__n_components=0.5026985989439481;, score=0.837 total time=  11.7s
# [CV 5/5; 1/1] START LR__C=182.78053240289583, LR__penalty=l2, PCA__n_components=0.5026985989439481
# [CV 5/5; 1/1] END LR__C=182.78053240289583, LR__penalty=l2, PCA__n_components=0.5026985989439481;, score=0.844 total time=  11.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=13.847456820046851, LR__penalty=l1, PCA__n_components=0.7066008921866787
# [CV 1/5; 1/1] END LR__C=13.847456820046851, LR__penalty=l1, PCA__n_components=0.7066008921866787;, score=0.947 total time=  11.8s
# [CV 2/5; 1/1] START LR__C=13.847456820046851, LR__penalty=l1, PCA__n_components=0.7066008921866787
# [CV 2/5; 1/1] END LR__C=13.847456820046851, LR__penalty=l1, PCA__n_components=0.7066008921866787;, score=0.833 total time=  11.6s
# [CV 3/5; 1/1] START LR__C=13.847456820046851, LR__penalty=l1, PCA__n_components=0.7066008921866787
# [CV 3/5; 1/1] END LR__C=13.847456820046851, LR__penalty=l1, PCA__n_components=0.7066008921866787;, score=0.927 total time=  13.2s
# [CV 4/5; 1/1] START LR__C=13.847456820046851, LR__penalty=l1, PCA__n_components=0.7066008921866787
# [CV 4/5; 1/1] END LR__C=13.847456820046851, LR__penalty=l1, PCA__n_components=0.7066008921866787;, score=0.780 total time=  11.9s
# [CV 5/5; 1/1] START LR__C=13.847456820046851, LR__penalty=l1, PCA__n_components=0.7066008921866787
# [CV 5/5; 1/1] END LR__C=13.847456820046851, LR__penalty=l1, PCA__n_components=0.7066008921866787;, score=0.923 total time=  11.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=0.5271220949249481, LR__penalty=l2, PCA__n_components=0.522179491317376
# [CV 1/5; 1/1] END LR__C=0.5271220949249481, LR__penalty=l2, PCA__n_components=0.522179491317376;, score=0.919 total time=  11.5s
# [CV 2/5; 1/1] START LR__C=0.5271220949249481, LR__penalty=l2, PCA__n_components=0.522179491317376
# [CV 2/5; 1/1] END LR__C=0.5271220949249481, LR__penalty=l2, PCA__n_components=0.522179491317376;, score=0.821 total time=  12.1s
# [CV 3/5; 1/1] START LR__C=0.5271220949249481, LR__penalty=l2, PCA__n_components=0.522179491317376
# [CV 3/5; 1/1] END LR__C=0.5271220949249481, LR__penalty=l2, PCA__n_components=0.522179491317376;, score=0.789 total time=  12.0s
# [CV 4/5; 1/1] START LR__C=0.5271220949249481, LR__penalty=l2, PCA__n_components=0.522179491317376
# [CV 4/5; 1/1] END LR__C=0.5271220949249481, LR__penalty=l2, PCA__n_components=0.522179491317376;, score=0.837 total time=  11.5s
# [CV 5/5; 1/1] START LR__C=0.5271220949249481, LR__penalty=l2, PCA__n_components=0.522179491317376
# [CV 5/5; 1/1] END LR__C=0.5271220949249481, LR__penalty=l2, PCA__n_components=0.522179491317376;, score=0.857 total time=  11.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=0.8204459006726665, LR__penalty=l2, PCA__n_components=0.7501007393111264
# [CV 1/5; 1/1] END LR__C=0.8204459006726665, LR__penalty=l2, PCA__n_components=0.7501007393111264;, score=0.919 total time=  11.1s
# [CV 2/5; 1/1] START LR__C=0.8204459006726665, LR__penalty=l2, PCA__n_components=0.7501007393111264
# [CV 2/5; 1/1] END LR__C=0.8204459006726665, LR__penalty=l2, PCA__n_components=0.7501007393111264;, score=0.833 total time=  11.0s
# [CV 3/5; 1/1] START LR__C=0.8204459006726665, LR__penalty=l2, PCA__n_components=0.7501007393111264
# [CV 3/5; 1/1] END LR__C=0.8204459006726665, LR__penalty=l2, PCA__n_components=0.7501007393111264;, score=0.833 total time=  11.5s
# [CV 4/5; 1/1] START LR__C=0.8204459006726665, LR__penalty=l2, PCA__n_components=0.7501007393111264
# [CV 4/5; 1/1] END LR__C=0.8204459006726665, LR__penalty=l2, PCA__n_components=0.7501007393111264;, score=0.821 total time=  11.6s
# [CV 5/5; 1/1] START LR__C=0.8204459006726665, LR__penalty=l2, PCA__n_components=0.7501007393111264
# [CV 5/5; 1/1] END LR__C=0.8204459006726665, LR__penalty=l2, PCA__n_components=0.7501007393111264;, score=0.974 total time=  11.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=6.891881588550671, LR__penalty=l2, PCA__n_components=0.95
# [CV 1/5; 1/1] END LR__C=6.891881588550671, LR__penalty=l2, PCA__n_components=0.95;, score=0.895 total time=  11.9s
# [CV 2/5; 1/1] START LR__C=6.891881588550671, LR__penalty=l2, PCA__n_components=0.95
# [CV 2/5; 1/1] END LR__C=6.891881588550671, LR__penalty=l2, PCA__n_components=0.95;, score=0.800 total time=  11.3s
# [CV 3/5; 1/1] START LR__C=6.891881588550671, LR__penalty=l2, PCA__n_components=0.95
# [CV 3/5; 1/1] END LR__C=6.891881588550671, LR__penalty=l2, PCA__n_components=0.95;, score=0.919 total time=  11.2s
# [CV 4/5; 1/1] START LR__C=6.891881588550671, LR__penalty=l2, PCA__n_components=0.95
# [CV 4/5; 1/1] END LR__C=6.891881588550671, LR__penalty=l2, PCA__n_components=0.95;, score=0.923 total time=  11.8s
# [CV 5/5; 1/1] START LR__C=6.891881588550671, LR__penalty=l2, PCA__n_components=0.95
# [CV 5/5; 1/1] END LR__C=6.891881588550671, LR__penalty=l2, PCA__n_components=0.95;, score=0.952 total time=  12.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=0.1, LR__penalty=l2, PCA__n_components=0.901660020775664
# [CV 1/5; 1/1] END LR__C=0.1, LR__penalty=l2, PCA__n_components=0.901660020775664;, score=0.865 total time=  14.0s
# [CV 2/5; 1/1] START LR__C=0.1, LR__penalty=l2, PCA__n_components=0.901660020775664
# [CV 2/5; 1/1] END LR__C=0.1, LR__penalty=l2, PCA__n_components=0.901660020775664;, score=0.800 total time=  12.3s
# [CV 3/5; 1/1] START LR__C=0.1, LR__penalty=l2, PCA__n_components=0.901660020775664
# [CV 3/5; 1/1] END LR__C=0.1, LR__penalty=l2, PCA__n_components=0.901660020775664;, score=0.889 total time=  11.6s
# [CV 4/5; 1/1] START LR__C=0.1, LR__penalty=l2, PCA__n_components=0.901660020775664
# [CV 4/5; 1/1] END LR__C=0.1, LR__penalty=l2, PCA__n_components=0.901660020775664;, score=0.895 total time=  13.7s
# [CV 5/5; 1/1] START LR__C=0.1, LR__penalty=l2, PCA__n_components=0.901660020775664
# [CV 5/5; 1/1] END LR__C=0.1, LR__penalty=l2, PCA__n_components=0.901660020775664;, score=1.000 total time=  12.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=1000.0, LR__penalty=l1, PCA__n_components=0.750274184723708
# [CV 1/5; 1/1] END LR__C=1000.0, LR__penalty=l1, PCA__n_components=0.750274184723708;, score=0.947 total time=  12.1s
# [CV 2/5; 1/1] START LR__C=1000.0, LR__penalty=l1, PCA__n_components=0.750274184723708
# d:\Projetos Pessoais\ADPrediction\.venv\Lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 2/5; 1/1] END LR__C=1000.0, LR__penalty=l1, PCA__n_components=0.750274184723708;, score=0.789 total time=  12.3s
# [CV 3/5; 1/1] START LR__C=1000.0, LR__penalty=l1, PCA__n_components=0.750274184723708
# [CV 3/5; 1/1] END LR__C=1000.0, LR__penalty=l1, PCA__n_components=0.750274184723708;, score=0.818 total time=  12.8s
# [CV 4/5; 1/1] START LR__C=1000.0, LR__penalty=l1, PCA__n_components=0.750274184723708
# [CV 4/5; 1/1] END LR__C=1000.0, LR__penalty=l1, PCA__n_components=0.750274184723708;, score=0.762 total time=  12.7s
# [CV 5/5; 1/1] START LR__C=1000.0, LR__penalty=l1, PCA__n_components=0.750274184723708
# [CV 5/5; 1/1] END LR__C=1000.0, LR__penalty=l1, PCA__n_components=0.750274184723708;, score=1.000 total time=  12.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=1.4288484094905765, LR__penalty=l1, PCA__n_components=0.95
# [CV 1/5; 1/1] END LR__C=1.4288484094905765, LR__penalty=l1, PCA__n_components=0.95;, score=0.923 total time=  11.8s
# [CV 2/5; 1/1] START LR__C=1.4288484094905765, LR__penalty=l1, PCA__n_components=0.95
# [CV 2/5; 1/1] END LR__C=1.4288484094905765, LR__penalty=l1, PCA__n_components=0.95;, score=0.895 total time=  11.9s
# [CV 3/5; 1/1] START LR__C=1.4288484094905765, LR__penalty=l1, PCA__n_components=0.95
# [CV 3/5; 1/1] END LR__C=1.4288484094905765, LR__penalty=l1, PCA__n_components=0.95;, score=0.811 total time=  11.6s
# [CV 4/5; 1/1] START LR__C=1.4288484094905765, LR__penalty=l1, PCA__n_components=0.95
# [CV 4/5; 1/1] END LR__C=1.4288484094905765, LR__penalty=l1, PCA__n_components=0.95;, score=0.878 total time=  11.8s
# [CV 5/5; 1/1] START LR__C=1.4288484094905765, LR__penalty=l1, PCA__n_components=0.95
# [CV 5/5; 1/1] END LR__C=1.4288484094905765, LR__penalty=l1, PCA__n_components=0.95;, score=0.930 total time=  12.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=0.1, LR__penalty=l2, PCA__n_components=0.95...........
# [CV 1/5; 1/1] END LR__C=0.1, LR__penalty=l2, PCA__n_components=0.95;, score=0.895 total time=  11.5s
# [CV 2/5; 1/1] START LR__C=0.1, LR__penalty=l2, PCA__n_components=0.95...........
# [CV 2/5; 1/1] END LR__C=0.1, LR__penalty=l2, PCA__n_components=0.95;, score=0.765 total time=  11.6s
# [CV 3/5; 1/1] START LR__C=0.1, LR__penalty=l2, PCA__n_components=0.95...........
# [CV 3/5; 1/1] END LR__C=0.1, LR__penalty=l2, PCA__n_components=0.95;, score=0.919 total time=  11.2s
# [CV 4/5; 1/1] START LR__C=0.1, LR__penalty=l2, PCA__n_components=0.95...........
# [CV 4/5; 1/1] END LR__C=0.1, LR__penalty=l2, PCA__n_components=0.95;, score=0.919 total time=  11.3s
# [CV 5/5; 1/1] START LR__C=0.1, LR__penalty=l2, PCA__n_components=0.95...........
# [CV 5/5; 1/1] END LR__C=0.1, LR__penalty=l2, PCA__n_components=0.95;, score=0.976 total time=  11.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=0.1, LR__penalty=l1, PCA__n_components=0.95...........
# [CV 1/5; 1/1] END LR__C=0.1, LR__penalty=l1, PCA__n_components=0.95;, score=0.857 total time=  12.1s
# [CV 2/5; 1/1] START LR__C=0.1, LR__penalty=l1, PCA__n_components=0.95...........
# [CV 2/5; 1/1] END LR__C=0.1, LR__penalty=l1, PCA__n_components=0.95;, score=0.905 total time=  13.9s
# [CV 3/5; 1/1] START LR__C=0.1, LR__penalty=l1, PCA__n_components=0.95...........
# [CV 3/5; 1/1] END LR__C=0.1, LR__penalty=l1, PCA__n_components=0.95;, score=0.778 total time=  11.5s
# [CV 4/5; 1/1] START LR__C=0.1, LR__penalty=l1, PCA__n_components=0.95...........
# [CV 4/5; 1/1] END LR__C=0.1, LR__penalty=l1, PCA__n_components=0.95;, score=0.857 total time=  11.2s
# [CV 5/5; 1/1] START LR__C=0.1, LR__penalty=l1, PCA__n_components=0.95...........
# [CV 5/5; 1/1] END LR__C=0.1, LR__penalty=l1, PCA__n_components=0.95;, score=0.905 total time=  11.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=0.4048373811622413, LR__penalty=l1, PCA__n_components=0.9349998908685746
# [CV 1/5; 1/1] END LR__C=0.4048373811622413, LR__penalty=l1, PCA__n_components=0.9349998908685746;, score=0.923 total time=  11.3s
# [CV 2/5; 1/1] START LR__C=0.4048373811622413, LR__penalty=l1, PCA__n_components=0.9349998908685746
# [CV 2/5; 1/1] END LR__C=0.4048373811622413, LR__penalty=l1, PCA__n_components=0.9349998908685746;, score=0.923 total time=  11.2s
# [CV 3/5; 1/1] START LR__C=0.4048373811622413, LR__penalty=l1, PCA__n_components=0.9349998908685746
# [CV 3/5; 1/1] END LR__C=0.4048373811622413, LR__penalty=l1, PCA__n_components=0.9349998908685746;, score=0.833 total time=  11.6s
# [CV 4/5; 1/1] START LR__C=0.4048373811622413, LR__penalty=l1, PCA__n_components=0.9349998908685746
# [CV 4/5; 1/1] END LR__C=0.4048373811622413, LR__penalty=l1, PCA__n_components=0.9349998908685746;, score=0.829 total time=  11.9s
# [CV 5/5; 1/1] START LR__C=0.4048373811622413, LR__penalty=l1, PCA__n_components=0.9349998908685746
# [CV 5/5; 1/1] END LR__C=0.4048373811622413, LR__penalty=l1, PCA__n_components=0.9349998908685746;, score=1.000 total time=  11.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=0.2705950798482818, LR__penalty=l1, PCA__n_components=0.7932323455775949
# [CV 1/5; 1/1] END LR__C=0.2705950798482818, LR__penalty=l1, PCA__n_components=0.7932323455775949;, score=0.947 total time=  11.9s
# [CV 2/5; 1/1] START LR__C=0.2705950798482818, LR__penalty=l1, PCA__n_components=0.7932323455775949
# [CV 2/5; 1/1] END LR__C=0.2705950798482818, LR__penalty=l1, PCA__n_components=0.7932323455775949;, score=0.950 total time=  12.6s
# [CV 3/5; 1/1] START LR__C=0.2705950798482818, LR__penalty=l1, PCA__n_components=0.7932323455775949
# [CV 3/5; 1/1] END LR__C=0.2705950798482818, LR__penalty=l1, PCA__n_components=0.7932323455775949;, score=0.800 total time=  11.7s
# [CV 4/5; 1/1] START LR__C=0.2705950798482818, LR__penalty=l1, PCA__n_components=0.7932323455775949
# [CV 4/5; 1/1] END LR__C=0.2705950798482818, LR__penalty=l1, PCA__n_components=0.7932323455775949;, score=0.829 total time=  12.1s
# [CV 5/5; 1/1] START LR__C=0.2705950798482818, LR__penalty=l1, PCA__n_components=0.7932323455775949
# [CV 5/5; 1/1] END LR__C=0.2705950798482818, LR__penalty=l1, PCA__n_components=0.7932323455775949;, score=0.974 total time=  11.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=20.739556671388975, LR__penalty=l2, PCA__n_components=0.8104186482001772
# [CV 1/5; 1/1] END LR__C=20.739556671388975, LR__penalty=l2, PCA__n_components=0.8104186482001772;, score=0.872 total time=  12.2s
# [CV 2/5; 1/1] START LR__C=20.739556671388975, LR__penalty=l2, PCA__n_components=0.8104186482001772
# [CV 2/5; 1/1] END LR__C=20.739556671388975, LR__penalty=l2, PCA__n_components=0.8104186482001772;, score=0.864 total time=  18.1s
# [CV 3/5; 1/1] START LR__C=20.739556671388975, LR__penalty=l2, PCA__n_components=0.8104186482001772
# [CV 3/5; 1/1] END LR__C=20.739556671388975, LR__penalty=l2, PCA__n_components=0.8104186482001772;, score=0.900 total time=  15.4s
# [CV 4/5; 1/1] START LR__C=20.739556671388975, LR__penalty=l2, PCA__n_components=0.8104186482001772
# [CV 4/5; 1/1] END LR__C=20.739556671388975, LR__penalty=l2, PCA__n_components=0.8104186482001772;, score=0.850 total time=  12.5s
# [CV 5/5; 1/1] START LR__C=20.739556671388975, LR__penalty=l2, PCA__n_components=0.8104186482001772
# [CV 5/5; 1/1] END LR__C=20.739556671388975, LR__penalty=l2, PCA__n_components=0.8104186482001772;, score=0.976 total time=  12.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=46.68236346596899, LR__penalty=l2, PCA__n_components=0.95
# [CV 1/5; 1/1] END LR__C=46.68236346596899, LR__penalty=l2, PCA__n_components=0.95;, score=0.895 total time=  13.0s
# [CV 2/5; 1/1] START LR__C=46.68236346596899, LR__penalty=l2, PCA__n_components=0.95
# [CV 2/5; 1/1] END LR__C=46.68236346596899, LR__penalty=l2, PCA__n_components=0.95;, score=0.800 total time=  12.3s
# [CV 3/5; 1/1] START LR__C=46.68236346596899, LR__penalty=l2, PCA__n_components=0.95
# [CV 3/5; 1/1] END LR__C=46.68236346596899, LR__penalty=l2, PCA__n_components=0.95;, score=0.919 total time=  12.3s
# [CV 4/5; 1/1] START LR__C=46.68236346596899, LR__penalty=l2, PCA__n_components=0.95
# [CV 4/5; 1/1] END LR__C=46.68236346596899, LR__penalty=l2, PCA__n_components=0.95;, score=0.923 total time=  12.3s
# [CV 5/5; 1/1] START LR__C=46.68236346596899, LR__penalty=l2, PCA__n_components=0.95
# [CV 5/5; 1/1] END LR__C=46.68236346596899, LR__penalty=l2, PCA__n_components=0.95;, score=0.952 total time=  12.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=7.323025024172228, LR__penalty=l2, PCA__n_components=0.6492067220731881
# [CV 1/5; 1/1] END LR__C=7.323025024172228, LR__penalty=l2, PCA__n_components=0.6492067220731881;, score=0.947 total time=  12.2s
# [CV 2/5; 1/1] START LR__C=7.323025024172228, LR__penalty=l2, PCA__n_components=0.6492067220731881
# [CV 2/5; 1/1] END LR__C=7.323025024172228, LR__penalty=l2, PCA__n_components=0.6492067220731881;, score=0.865 total time=  12.1s
# [CV 3/5; 1/1] START LR__C=7.323025024172228, LR__penalty=l2, PCA__n_components=0.6492067220731881
# [CV 3/5; 1/1] END LR__C=7.323025024172228, LR__penalty=l2, PCA__n_components=0.6492067220731881;, score=0.895 total time=  12.8s
# [CV 4/5; 1/1] START LR__C=7.323025024172228, LR__penalty=l2, PCA__n_components=0.6492067220731881
# [CV 4/5; 1/1] END LR__C=7.323025024172228, LR__penalty=l2, PCA__n_components=0.6492067220731881;, score=0.800 total time=  12.3s
# [CV 5/5; 1/1] START LR__C=7.323025024172228, LR__penalty=l2, PCA__n_components=0.6492067220731881
# [CV 5/5; 1/1] END LR__C=7.323025024172228, LR__penalty=l2, PCA__n_components=0.6492067220731881;, score=0.923 total time=  13.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=0.21414407090711543, LR__penalty=l1, PCA__n_components=0.95
# [CV 1/5; 1/1] END LR__C=0.21414407090711543, LR__penalty=l1, PCA__n_components=0.95;, score=0.947 total time=  12.7s
# [CV 2/5; 1/1] START LR__C=0.21414407090711543, LR__penalty=l1, PCA__n_components=0.95
# [CV 2/5; 1/1] END LR__C=0.21414407090711543, LR__penalty=l1, PCA__n_components=0.95;, score=0.950 total time=  12.3s
# [CV 3/5; 1/1] START LR__C=0.21414407090711543, LR__penalty=l1, PCA__n_components=0.95
# [CV 3/5; 1/1] END LR__C=0.21414407090711543, LR__penalty=l1, PCA__n_components=0.95;, score=0.800 total time=  12.4s
# [CV 4/5; 1/1] START LR__C=0.21414407090711543, LR__penalty=l1, PCA__n_components=0.95
# [CV 4/5; 1/1] END LR__C=0.21414407090711543, LR__penalty=l1, PCA__n_components=0.95;, score=0.829 total time=  12.1s
# [CV 5/5; 1/1] START LR__C=0.21414407090711543, LR__penalty=l1, PCA__n_components=0.95
# [CV 5/5; 1/1] END LR__C=0.21414407090711543, LR__penalty=l1, PCA__n_components=0.95;, score=0.976 total time=  12.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=3.620864053711082, LR__penalty=l2, PCA__n_components=0.95
# [CV 1/5; 1/1] END LR__C=3.620864053711082, LR__penalty=l2, PCA__n_components=0.95;, score=0.895 total time=  12.0s
# [CV 2/5; 1/1] START LR__C=3.620864053711082, LR__penalty=l2, PCA__n_components=0.95
# [CV 2/5; 1/1] END LR__C=3.620864053711082, LR__penalty=l2, PCA__n_components=0.95;, score=0.800 total time=  11.9s
# [CV 3/5; 1/1] START LR__C=3.620864053711082, LR__penalty=l2, PCA__n_components=0.95
# [CV 3/5; 1/1] END LR__C=3.620864053711082, LR__penalty=l2, PCA__n_components=0.95;, score=0.919 total time=  11.9s
# [CV 4/5; 1/1] START LR__C=3.620864053711082, LR__penalty=l2, PCA__n_components=0.95
# [CV 4/5; 1/1] END LR__C=3.620864053711082, LR__penalty=l2, PCA__n_components=0.95;, score=0.923 total time=  11.5s
# [CV 5/5; 1/1] START LR__C=3.620864053711082, LR__penalty=l2, PCA__n_components=0.95
# [CV 5/5; 1/1] END LR__C=3.620864053711082, LR__penalty=l2, PCA__n_components=0.95;, score=0.952 total time=  12.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=27.12686018890197, LR__penalty=l2, PCA__n_components=0.5
# [CV 1/5; 1/1] END LR__C=27.12686018890197, LR__penalty=l2, PCA__n_components=0.5;, score=0.919 total time=  11.7s
# [CV 2/5; 1/1] START LR__C=27.12686018890197, LR__penalty=l2, PCA__n_components=0.5
# [CV 2/5; 1/1] END LR__C=27.12686018890197, LR__penalty=l2, PCA__n_components=0.5;, score=0.800 total time=  11.7s
# [CV 3/5; 1/1] START LR__C=27.12686018890197, LR__penalty=l2, PCA__n_components=0.5
# [CV 3/5; 1/1] END LR__C=27.12686018890197, LR__penalty=l2, PCA__n_components=0.5;, score=0.757 total time=  11.9s
# [CV 4/5; 1/1] START LR__C=27.12686018890197, LR__penalty=l2, PCA__n_components=0.5
# [CV 4/5; 1/1] END LR__C=27.12686018890197, LR__penalty=l2, PCA__n_components=0.5;, score=0.837 total time=  11.9s
# [CV 5/5; 1/1] START LR__C=27.12686018890197, LR__penalty=l2, PCA__n_components=0.5
# [CV 5/5; 1/1] END LR__C=27.12686018890197, LR__penalty=l2, PCA__n_components=0.5;, score=0.844 total time=  11.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=1.469076231373549, LR__penalty=l2, PCA__n_components=0.8668088203036479
# [CV 1/5; 1/1] END LR__C=1.469076231373549, LR__penalty=l2, PCA__n_components=0.8668088203036479;, score=0.872 total time=  11.6s
# [CV 2/5; 1/1] START LR__C=1.469076231373549, LR__penalty=l2, PCA__n_components=0.8668088203036479
# [CV 2/5; 1/1] END LR__C=1.469076231373549, LR__penalty=l2, PCA__n_components=0.8668088203036479;, score=0.833 total time=  12.2s
# [CV 3/5; 1/1] START LR__C=1.469076231373549, LR__penalty=l2, PCA__n_components=0.8668088203036479
# [CV 3/5; 1/1] END LR__C=1.469076231373549, LR__penalty=l2, PCA__n_components=0.8668088203036479;, score=0.865 total time=  12.2s
# [CV 4/5; 1/1] START LR__C=1.469076231373549, LR__penalty=l2, PCA__n_components=0.8668088203036479
# [CV 4/5; 1/1] END LR__C=1.469076231373549, LR__penalty=l2, PCA__n_components=0.8668088203036479;, score=0.878 total time=  12.4s
# [CV 5/5; 1/1] START LR__C=1.469076231373549, LR__penalty=l2, PCA__n_components=0.8668088203036479
# [CV 5/5; 1/1] END LR__C=1.469076231373549, LR__penalty=l2, PCA__n_components=0.8668088203036479;, score=0.976 total time=  12.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=878.1885610967494, LR__penalty=l2, PCA__n_components=0.94909227458675
# [CV 1/5; 1/1] END LR__C=878.1885610967494, LR__penalty=l2, PCA__n_components=0.94909227458675;, score=0.919 total time=  12.2s
# [CV 2/5; 1/1] START LR__C=878.1885610967494, LR__penalty=l2, PCA__n_components=0.94909227458675
# [CV 2/5; 1/1] END LR__C=878.1885610967494, LR__penalty=l2, PCA__n_components=0.94909227458675;, score=0.743 total time=  13.1s
# [CV 3/5; 1/1] START LR__C=878.1885610967494, LR__penalty=l2, PCA__n_components=0.94909227458675
# [CV 3/5; 1/1] END LR__C=878.1885610967494, LR__penalty=l2, PCA__n_components=0.94909227458675;, score=0.919 total time=  12.7s
# [CV 4/5; 1/1] START LR__C=878.1885610967494, LR__penalty=l2, PCA__n_components=0.94909227458675
# [CV 4/5; 1/1] END LR__C=878.1885610967494, LR__penalty=l2, PCA__n_components=0.94909227458675;, score=0.923 total time=  11.9s
# [CV 5/5; 1/1] START LR__C=878.1885610967494, LR__penalty=l2, PCA__n_components=0.94909227458675
# [CV 5/5; 1/1] END LR__C=878.1885610967494, LR__penalty=l2, PCA__n_components=0.94909227458675;, score=0.952 total time=  12.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=365.065215587776, LR__penalty=l1, PCA__n_components=0.9265247237069165
# [CV 1/5; 1/1] END LR__C=365.065215587776, LR__penalty=l1, PCA__n_components=0.9265247237069165;, score=0.895 total time=  12.4s
# [CV 2/5; 1/1] START LR__C=365.065215587776, LR__penalty=l1, PCA__n_components=0.9265247237069165
# [CV 2/5; 1/1] END LR__C=365.065215587776, LR__penalty=l1, PCA__n_components=0.9265247237069165;, score=0.800 total time=  12.5s
# [CV 3/5; 1/1] START LR__C=365.065215587776, LR__penalty=l1, PCA__n_components=0.9265247237069165
# [CV 3/5; 1/1] END LR__C=365.065215587776, LR__penalty=l1, PCA__n_components=0.9265247237069165;, score=0.865 total time=  12.3s
# [CV 4/5; 1/1] START LR__C=365.065215587776, LR__penalty=l1, PCA__n_components=0.9265247237069165
# [CV 4/5; 1/1] END LR__C=365.065215587776, LR__penalty=l1, PCA__n_components=0.9265247237069165;, score=0.927 total time=  12.6s
# [CV 5/5; 1/1] START LR__C=365.065215587776, LR__penalty=l1, PCA__n_components=0.9265247237069165
# [CV 5/5; 1/1] END LR__C=365.065215587776, LR__penalty=l1, PCA__n_components=0.9265247237069165;, score=0.976 total time=  13.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=0.1, LR__penalty=l2, PCA__n_components=0.8226187006665726
# [CV 1/5; 1/1] END LR__C=0.1, LR__penalty=l2, PCA__n_components=0.8226187006665726;, score=0.895 total time=  12.3s
# [CV 2/5; 1/1] START LR__C=0.1, LR__penalty=l2, PCA__n_components=0.8226187006665726
# [CV 2/5; 1/1] END LR__C=0.1, LR__penalty=l2, PCA__n_components=0.8226187006665726;, score=0.833 total time=  12.0s
# [CV 3/5; 1/1] START LR__C=0.1, LR__penalty=l2, PCA__n_components=0.8226187006665726
# [CV 3/5; 1/1] END LR__C=0.1, LR__penalty=l2, PCA__n_components=0.8226187006665726;, score=0.919 total time=  15.6s
# [CV 4/5; 1/1] START LR__C=0.1, LR__penalty=l2, PCA__n_components=0.8226187006665726
# [CV 4/5; 1/1] END LR__C=0.1, LR__penalty=l2, PCA__n_components=0.8226187006665726;, score=0.895 total time=  13.6s
# [CV 5/5; 1/1] START LR__C=0.1, LR__penalty=l2, PCA__n_components=0.8226187006665726
# [CV 5/5; 1/1] END LR__C=0.1, LR__penalty=l2, PCA__n_components=0.8226187006665726;, score=0.974 total time=  14.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=1000.0, LR__penalty=l2, PCA__n_components=0.6583190292200556
# [CV 1/5; 1/1] END LR__C=1000.0, LR__penalty=l2, PCA__n_components=0.6583190292200556;, score=0.923 total time=  13.5s
# [CV 2/5; 1/1] START LR__C=1000.0, LR__penalty=l2, PCA__n_components=0.6583190292200556
# [CV 2/5; 1/1] END LR__C=1000.0, LR__penalty=l2, PCA__n_components=0.6583190292200556;, score=0.865 total time=  12.9s
# [CV 3/5; 1/1] START LR__C=1000.0, LR__penalty=l2, PCA__n_components=0.6583190292200556
# [CV 3/5; 1/1] END LR__C=1000.0, LR__penalty=l2, PCA__n_components=0.6583190292200556;, score=0.895 total time=  12.5s
# [CV 4/5; 1/1] START LR__C=1000.0, LR__penalty=l2, PCA__n_components=0.6583190292200556
# [CV 4/5; 1/1] END LR__C=1000.0, LR__penalty=l2, PCA__n_components=0.6583190292200556;, score=0.800 total time=  12.4s
# [CV 5/5; 1/1] START LR__C=1000.0, LR__penalty=l2, PCA__n_components=0.6583190292200556
# [CV 5/5; 1/1] END LR__C=1000.0, LR__penalty=l2, PCA__n_components=0.6583190292200556;, score=0.923 total time=  13.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=0.1, LR__penalty=l1, PCA__n_components=0.6120816918253984
# [CV 1/5; 1/1] END LR__C=0.1, LR__penalty=l1, PCA__n_components=0.6120816918253984;, score=0.833 total time=  13.3s
# [CV 2/5; 1/1] START LR__C=0.1, LR__penalty=l1, PCA__n_components=0.6120816918253984
# [CV 2/5; 1/1] END LR__C=0.1, LR__penalty=l1, PCA__n_components=0.6120816918253984;, score=0.905 total time=  12.8s
# [CV 3/5; 1/1] START LR__C=0.1, LR__penalty=l1, PCA__n_components=0.6120816918253984
# [CV 3/5; 1/1] END LR__C=0.1, LR__penalty=l1, PCA__n_components=0.6120816918253984;, score=0.778 total time=  14.0s
# [CV 4/5; 1/1] START LR__C=0.1, LR__penalty=l1, PCA__n_components=0.6120816918253984
# [CV 4/5; 1/1] END LR__C=0.1, LR__penalty=l1, PCA__n_components=0.6120816918253984;, score=0.857 total time=  12.3s
# [CV 5/5; 1/1] START LR__C=0.1, LR__penalty=l1, PCA__n_components=0.6120816918253984
# [CV 5/5; 1/1] END LR__C=0.1, LR__penalty=l1, PCA__n_components=0.6120816918253984;, score=0.905 total time=  12.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=0.10183412936499243, LR__penalty=l2, PCA__n_components=0.8514553799391955
# [CV 1/5; 1/1] END LR__C=0.10183412936499243, LR__penalty=l2, PCA__n_components=0.8514553799391955;, score=0.895 total time=  11.8s
# [CV 2/5; 1/1] START LR__C=0.10183412936499243, LR__penalty=l2, PCA__n_components=0.8514553799391955
# [CV 2/5; 1/1] END LR__C=0.10183412936499243, LR__penalty=l2, PCA__n_components=0.8514553799391955;, score=0.765 total time=  11.9s
# [CV 3/5; 1/1] START LR__C=0.10183412936499243, LR__penalty=l2, PCA__n_components=0.8514553799391955
# [CV 3/5; 1/1] END LR__C=0.10183412936499243, LR__penalty=l2, PCA__n_components=0.8514553799391955;, score=0.895 total time=  12.6s
# [CV 4/5; 1/1] START LR__C=0.10183412936499243, LR__penalty=l2, PCA__n_components=0.8514553799391955
# [CV 4/5; 1/1] END LR__C=0.10183412936499243, LR__penalty=l2, PCA__n_components=0.8514553799391955;, score=0.923 total time=  12.4s
# [CV 5/5; 1/1] START LR__C=0.10183412936499243, LR__penalty=l2, PCA__n_components=0.8514553799391955
# [CV 5/5; 1/1] END LR__C=0.10183412936499243, LR__penalty=l2, PCA__n_components=0.8514553799391955;, score=1.000 total time=  12.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=976.50803093188, LR__penalty=l1, PCA__n_components=0.6036986844370452
# [CV 1/5; 1/1] END LR__C=976.50803093188, LR__penalty=l1, PCA__n_components=0.6036986844370452;, score=0.923 total time=  12.1s
# [CV 2/5; 1/1] START LR__C=976.50803093188, LR__penalty=l1, PCA__n_components=0.6036986844370452
# [CV 2/5; 1/1] END LR__C=976.50803093188, LR__penalty=l1, PCA__n_components=0.6036986844370452;, score=0.865 total time=  12.0s
# [CV 3/5; 1/1] START LR__C=976.50803093188, LR__penalty=l1, PCA__n_components=0.6036986844370452
# [CV 3/5; 1/1] END LR__C=976.50803093188, LR__penalty=l1, PCA__n_components=0.6036986844370452;, score=0.895 total time=  11.9s
# [CV 4/5; 1/1] START LR__C=976.50803093188, LR__penalty=l1, PCA__n_components=0.6036986844370452
# [CV 4/5; 1/1] END LR__C=976.50803093188, LR__penalty=l1, PCA__n_components=0.6036986844370452;, score=0.905 total time=  12.2s
# [CV 5/5; 1/1] START LR__C=976.50803093188, LR__penalty=l1, PCA__n_components=0.6036986844370452
# [CV 5/5; 1/1] END LR__C=976.50803093188, LR__penalty=l1, PCA__n_components=0.6036986844370452;, score=0.923 total time=  12.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=0.1, LR__penalty=l1, PCA__n_components=0.8148340498888978
# [CV 1/5; 1/1] END LR__C=0.1, LR__penalty=l1, PCA__n_components=0.8148340498888978;, score=0.857 total time=  12.3s
# [CV 2/5; 1/1] START LR__C=0.1, LR__penalty=l1, PCA__n_components=0.8148340498888978
# [CV 2/5; 1/1] END LR__C=0.1, LR__penalty=l1, PCA__n_components=0.8148340498888978;, score=0.905 total time=  11.6s
# [CV 3/5; 1/1] START LR__C=0.1, LR__penalty=l1, PCA__n_components=0.8148340498888978
# [CV 3/5; 1/1] END LR__C=0.1, LR__penalty=l1, PCA__n_components=0.8148340498888978;, score=0.778 total time=  12.1s
# [CV 4/5; 1/1] START LR__C=0.1, LR__penalty=l1, PCA__n_components=0.8148340498888978
# [CV 4/5; 1/1] END LR__C=0.1, LR__penalty=l1, PCA__n_components=0.8148340498888978;, score=0.857 total time=  20.2s
# [CV 5/5; 1/1] START LR__C=0.1, LR__penalty=l1, PCA__n_components=0.8148340498888978
# [CV 5/5; 1/1] END LR__C=0.1, LR__penalty=l1, PCA__n_components=0.8148340498888978;, score=0.905 total time=  12.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=1000.0, LR__penalty=l1, PCA__n_components=0.6347436892372738
# [CV 1/5; 1/1] END LR__C=1000.0, LR__penalty=l1, PCA__n_components=0.6347436892372738;, score=0.923 total time=  12.1s
# [CV 2/5; 1/1] START LR__C=1000.0, LR__penalty=l1, PCA__n_components=0.6347436892372738
# [CV 2/5; 1/1] END LR__C=1000.0, LR__penalty=l1, PCA__n_components=0.6347436892372738;, score=0.865 total time=  12.2s
# [CV 3/5; 1/1] START LR__C=1000.0, LR__penalty=l1, PCA__n_components=0.6347436892372738
# [CV 3/5; 1/1] END LR__C=1000.0, LR__penalty=l1, PCA__n_components=0.6347436892372738;, score=0.895 total time=  12.7s
# [CV 4/5; 1/1] START LR__C=1000.0, LR__penalty=l1, PCA__n_components=0.6347436892372738
# [CV 4/5; 1/1] END LR__C=1000.0, LR__penalty=l1, PCA__n_components=0.6347436892372738;, score=0.884 total time=  11.8s
# [CV 5/5; 1/1] START LR__C=1000.0, LR__penalty=l1, PCA__n_components=0.6347436892372738
# [CV 5/5; 1/1] END LR__C=1000.0, LR__penalty=l1, PCA__n_components=0.6347436892372738;, score=0.923 total time=  13.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=0.31516230895077046, LR__penalty=l1, PCA__n_components=0.8837398097269251
# [CV 1/5; 1/1] END LR__C=0.31516230895077046, LR__penalty=l1, PCA__n_components=0.8837398097269251;, score=0.923 total time=  12.7s
# [CV 2/5; 1/1] START LR__C=0.31516230895077046, LR__penalty=l1, PCA__n_components=0.8837398097269251
# [CV 2/5; 1/1] END LR__C=0.31516230895077046, LR__penalty=l1, PCA__n_components=0.8837398097269251;, score=0.950 total time=  12.4s
# [CV 3/5; 1/1] START LR__C=0.31516230895077046, LR__penalty=l1, PCA__n_components=0.8837398097269251
# [CV 3/5; 1/1] END LR__C=0.31516230895077046, LR__penalty=l1, PCA__n_components=0.8837398097269251;, score=0.800 total time=  12.5s
# [CV 4/5; 1/1] START LR__C=0.31516230895077046, LR__penalty=l1, PCA__n_components=0.8837398097269251
# [CV 4/5; 1/1] END LR__C=0.31516230895077046, LR__penalty=l1, PCA__n_components=0.8837398097269251;, score=0.800 total time=  12.7s
# [CV 5/5; 1/1] START LR__C=0.31516230895077046, LR__penalty=l1, PCA__n_components=0.8837398097269251
# [CV 5/5; 1/1] END LR__C=0.31516230895077046, LR__penalty=l1, PCA__n_components=0.8837398097269251;, score=1.000 total time=  11.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=0.24608580230599433, LR__penalty=l1, PCA__n_components=0.8866090871877897
# [CV 1/5; 1/1] END LR__C=0.24608580230599433, LR__penalty=l1, PCA__n_components=0.8866090871877897;, score=0.947 total time=  12.5s
# [CV 2/5; 1/1] START LR__C=0.24608580230599433, LR__penalty=l1, PCA__n_components=0.8866090871877897
# [CV 2/5; 1/1] END LR__C=0.24608580230599433, LR__penalty=l1, PCA__n_components=0.8866090871877897;, score=0.950 total time=  12.6s
# [CV 3/5; 1/1] START LR__C=0.24608580230599433, LR__penalty=l1, PCA__n_components=0.8866090871877897
# [CV 3/5; 1/1] END LR__C=0.24608580230599433, LR__penalty=l1, PCA__n_components=0.8866090871877897;, score=0.800 total time=  12.2s
# [CV 4/5; 1/1] START LR__C=0.24608580230599433, LR__penalty=l1, PCA__n_components=0.8866090871877897
# [CV 4/5; 1/1] END LR__C=0.24608580230599433, LR__penalty=l1, PCA__n_components=0.8866090871877897;, score=0.829 total time=  12.8s
# [CV 5/5; 1/1] START LR__C=0.24608580230599433, LR__penalty=l1, PCA__n_components=0.8866090871877897
# [CV 5/5; 1/1] END LR__C=0.24608580230599433, LR__penalty=l1, PCA__n_components=0.8866090871877897;, score=0.974 total time=  12.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=894.5489077775958, LR__penalty=l1, PCA__n_components=0.9482487461304131
# [CV 1/5; 1/1] END LR__C=894.5489077775958, LR__penalty=l1, PCA__n_components=0.9482487461304131;, score=0.919 total time=  12.7s
# [CV 2/5; 1/1] START LR__C=894.5489077775958, LR__penalty=l1, PCA__n_components=0.9482487461304131
# [CV 2/5; 1/1] END LR__C=894.5489077775958, LR__penalty=l1, PCA__n_components=0.9482487461304131;, score=0.743 total time=  12.8s
# [CV 3/5; 1/1] START LR__C=894.5489077775958, LR__penalty=l1, PCA__n_components=0.9482487461304131
# [CV 3/5; 1/1] END LR__C=894.5489077775958, LR__penalty=l1, PCA__n_components=0.9482487461304131;, score=0.919 total time=  12.8s
# [CV 4/5; 1/1] START LR__C=894.5489077775958, LR__penalty=l1, PCA__n_components=0.9482487461304131
# [CV 4/5; 1/1] END LR__C=894.5489077775958, LR__penalty=l1, PCA__n_components=0.9482487461304131;, score=0.923 total time=  12.8s
# [CV 5/5; 1/1] START LR__C=894.5489077775958, LR__penalty=l1, PCA__n_components=0.9482487461304131
# [CV 5/5; 1/1] END LR__C=894.5489077775958, LR__penalty=l1, PCA__n_components=0.9482487461304131;, score=0.952 total time=  12.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=975.4208935193734, LR__penalty=l2, PCA__n_components=0.5923457409396349
# [CV 1/5; 1/1] END LR__C=975.4208935193734, LR__penalty=l2, PCA__n_components=0.5923457409396349;, score=0.923 total time=  12.4s
# [CV 2/5; 1/1] START LR__C=975.4208935193734, LR__penalty=l2, PCA__n_components=0.5923457409396349
# [CV 2/5; 1/1] END LR__C=975.4208935193734, LR__penalty=l2, PCA__n_components=0.5923457409396349;, score=0.865 total time=  12.2s
# [CV 3/5; 1/1] START LR__C=975.4208935193734, LR__penalty=l2, PCA__n_components=0.5923457409396349
# [CV 3/5; 1/1] END LR__C=975.4208935193734, LR__penalty=l2, PCA__n_components=0.5923457409396349;, score=0.865 total time=  12.1s
# [CV 4/5; 1/1] START LR__C=975.4208935193734, LR__penalty=l2, PCA__n_components=0.5923457409396349
# [CV 4/5; 1/1] END LR__C=975.4208935193734, LR__penalty=l2, PCA__n_components=0.5923457409396349;, score=0.905 total time=  12.6s
# [CV 5/5; 1/1] START LR__C=975.4208935193734, LR__penalty=l2, PCA__n_components=0.5923457409396349
# [CV 5/5; 1/1] END LR__C=975.4208935193734, LR__penalty=l2, PCA__n_components=0.5923457409396349;, score=0.900 total time=  12.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=62.00024921874504, LR__penalty=l2, PCA__n_components=0.6251710341733347
# [CV 1/5; 1/1] END LR__C=62.00024921874504, LR__penalty=l2, PCA__n_components=0.6251710341733347;, score=0.923 total time=  12.7s
# [CV 2/5; 1/1] START LR__C=62.00024921874504, LR__penalty=l2, PCA__n_components=0.6251710341733347
# [CV 2/5; 1/1] END LR__C=62.00024921874504, LR__penalty=l2, PCA__n_components=0.6251710341733347;, score=0.865 total time=  12.8s
# [CV 3/5; 1/1] START LR__C=62.00024921874504, LR__penalty=l2, PCA__n_components=0.6251710341733347
# [CV 3/5; 1/1] END LR__C=62.00024921874504, LR__penalty=l2, PCA__n_components=0.6251710341733347;, score=0.895 total time=  12.0s
# [CV 4/5; 1/1] START LR__C=62.00024921874504, LR__penalty=l2, PCA__n_components=0.6251710341733347
# [CV 4/5; 1/1] END LR__C=62.00024921874504, LR__penalty=l2, PCA__n_components=0.6251710341733347;, score=0.905 total time=  11.9s
# [CV 5/5; 1/1] START LR__C=62.00024921874504, LR__penalty=l2, PCA__n_components=0.6251710341733347
# [CV 5/5; 1/1] END LR__C=62.00024921874504, LR__penalty=l2, PCA__n_components=0.6251710341733347;, score=0.923 total time=  12.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=2.4865972717200036, LR__penalty=l2, PCA__n_components=0.9162248571103451
# [CV 1/5; 1/1] END LR__C=2.4865972717200036, LR__penalty=l2, PCA__n_components=0.9162248571103451;, score=0.865 total time=  12.9s
# [CV 2/5; 1/1] START LR__C=2.4865972717200036, LR__penalty=l2, PCA__n_components=0.9162248571103451
# [CV 2/5; 1/1] END LR__C=2.4865972717200036, LR__penalty=l2, PCA__n_components=0.9162248571103451;, score=0.833 total time=  11.8s
# [CV 3/5; 1/1] START LR__C=2.4865972717200036, LR__penalty=l2, PCA__n_components=0.9162248571103451
# [CV 3/5; 1/1] END LR__C=2.4865972717200036, LR__penalty=l2, PCA__n_components=0.9162248571103451;, score=0.919 total time=  12.0s
# [CV 4/5; 1/1] START LR__C=2.4865972717200036, LR__penalty=l2, PCA__n_components=0.9162248571103451
# [CV 4/5; 1/1] END LR__C=2.4865972717200036, LR__penalty=l2, PCA__n_components=0.9162248571103451;, score=0.950 total time=  11.5s
# [CV 5/5; 1/1] START LR__C=2.4865972717200036, LR__penalty=l2, PCA__n_components=0.9162248571103451
# [CV 5/5; 1/1] END LR__C=2.4865972717200036, LR__penalty=l2, PCA__n_components=0.9162248571103451;, score=0.930 total time=  11.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=958.1399310737696, LR__penalty=l1, PCA__n_components=0.681763716518357
# [CV 1/5; 1/1] END LR__C=958.1399310737696, LR__penalty=l1, PCA__n_components=0.681763716518357;, score=0.947 total time=  12.2s
# [CV 2/5; 1/1] START LR__C=958.1399310737696, LR__penalty=l1, PCA__n_components=0.681763716518357
# [CV 2/5; 1/1] END LR__C=958.1399310737696, LR__penalty=l1, PCA__n_components=0.681763716518357;, score=0.895 total time=  11.6s
# [CV 3/5; 1/1] START LR__C=958.1399310737696, LR__penalty=l1, PCA__n_components=0.681763716518357
# [CV 3/5; 1/1] END LR__C=958.1399310737696, LR__penalty=l1, PCA__n_components=0.681763716518357;, score=0.895 total time=  12.3s
# [CV 4/5; 1/1] START LR__C=958.1399310737696, LR__penalty=l1, PCA__n_components=0.681763716518357
# [CV 4/5; 1/1] END LR__C=958.1399310737696, LR__penalty=l1, PCA__n_components=0.681763716518357;, score=0.800 total time=  12.2s
# [CV 5/5; 1/1] START LR__C=958.1399310737696, LR__penalty=l1, PCA__n_components=0.681763716518357
# [CV 5/5; 1/1] END LR__C=958.1399310737696, LR__penalty=l1, PCA__n_components=0.681763716518357;, score=0.923 total time=  12.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=44.07516348401864, LR__penalty=l2, PCA__n_components=0.6077117495586484
# [CV 1/5; 1/1] END LR__C=44.07516348401864, LR__penalty=l2, PCA__n_components=0.6077117495586484;, score=0.923 total time=  11.9s
# [CV 2/5; 1/1] START LR__C=44.07516348401864, LR__penalty=l2, PCA__n_components=0.6077117495586484
# [CV 2/5; 1/1] END LR__C=44.07516348401864, LR__penalty=l2, PCA__n_components=0.6077117495586484;, score=0.865 total time=  11.9s
# [CV 3/5; 1/1] START LR__C=44.07516348401864, LR__penalty=l2, PCA__n_components=0.6077117495586484
# [CV 3/5; 1/1] END LR__C=44.07516348401864, LR__penalty=l2, PCA__n_components=0.6077117495586484;, score=0.895 total time=  12.3s
# [CV 4/5; 1/1] START LR__C=44.07516348401864, LR__penalty=l2, PCA__n_components=0.6077117495586484
# [CV 4/5; 1/1] END LR__C=44.07516348401864, LR__penalty=l2, PCA__n_components=0.6077117495586484;, score=0.905 total time=  12.0s
# [CV 5/5; 1/1] START LR__C=44.07516348401864, LR__penalty=l2, PCA__n_components=0.6077117495586484
# [CV 5/5; 1/1] END LR__C=44.07516348401864, LR__penalty=l2, PCA__n_components=0.6077117495586484;, score=0.923 total time=  13.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=82.68356684281908, LR__penalty=l2, PCA__n_components=0.6556624179956079
# [CV 1/5; 1/1] END LR__C=82.68356684281908, LR__penalty=l2, PCA__n_components=0.6556624179956079;, score=0.923 total time=  11.8s
# [CV 2/5; 1/1] START LR__C=82.68356684281908, LR__penalty=l2, PCA__n_components=0.6556624179956079
# [CV 2/5; 1/1] END LR__C=82.68356684281908, LR__penalty=l2, PCA__n_components=0.6556624179956079;, score=0.865 total time=  11.9s
# [CV 3/5; 1/1] START LR__C=82.68356684281908, LR__penalty=l2, PCA__n_components=0.6556624179956079
# [CV 3/5; 1/1] END LR__C=82.68356684281908, LR__penalty=l2, PCA__n_components=0.6556624179956079;, score=0.895 total time=  12.4s
# [CV 4/5; 1/1] START LR__C=82.68356684281908, LR__penalty=l2, PCA__n_components=0.6556624179956079
# [CV 4/5; 1/1] END LR__C=82.68356684281908, LR__penalty=l2, PCA__n_components=0.6556624179956079;, score=0.800 total time=  11.2s
# [CV 5/5; 1/1] START LR__C=82.68356684281908, LR__penalty=l2, PCA__n_components=0.6556624179956079
# [CV 5/5; 1/1] END LR__C=82.68356684281908, LR__penalty=l2, PCA__n_components=0.6556624179956079;, score=0.923 total time=  11.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=0.1, LR__penalty=l1, PCA__n_components=0.913617743261488
# [CV 1/5; 1/1] END LR__C=0.1, LR__penalty=l1, PCA__n_components=0.913617743261488;, score=0.857 total time=  11.7s
# [CV 2/5; 1/1] START LR__C=0.1, LR__penalty=l1, PCA__n_components=0.913617743261488
# [CV 2/5; 1/1] END LR__C=0.1, LR__penalty=l1, PCA__n_components=0.913617743261488;, score=0.905 total time=  12.1s
# [CV 3/5; 1/1] START LR__C=0.1, LR__penalty=l1, PCA__n_components=0.913617743261488
# [CV 3/5; 1/1] END LR__C=0.1, LR__penalty=l1, PCA__n_components=0.913617743261488;, score=0.778 total time=  11.3s
# [CV 4/5; 1/1] START LR__C=0.1, LR__penalty=l1, PCA__n_components=0.913617743261488
# [CV 4/5; 1/1] END LR__C=0.1, LR__penalty=l1, PCA__n_components=0.913617743261488;, score=0.857 total time=  11.6s
# [CV 5/5; 1/1] START LR__C=0.1, LR__penalty=l1, PCA__n_components=0.913617743261488
# [CV 5/5; 1/1] END LR__C=0.1, LR__penalty=l1, PCA__n_components=0.913617743261488;, score=0.905 total time=  11.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=49.88056698994767, LR__penalty=l2, PCA__n_components=0.7371077691077838
# [CV 1/5; 1/1] END LR__C=49.88056698994767, LR__penalty=l2, PCA__n_components=0.7371077691077838;, score=0.919 total time=  11.8s
# [CV 2/5; 1/1] START LR__C=49.88056698994767, LR__penalty=l2, PCA__n_components=0.7371077691077838
# [CV 2/5; 1/1] END LR__C=49.88056698994767, LR__penalty=l2, PCA__n_components=0.7371077691077838;, score=0.923 total time=  11.4s
# [CV 3/5; 1/1] START LR__C=49.88056698994767, LR__penalty=l2, PCA__n_components=0.7371077691077838
# [CV 3/5; 1/1] END LR__C=49.88056698994767, LR__penalty=l2, PCA__n_components=0.7371077691077838;, score=0.927 total time=  12.2s
# [CV 4/5; 1/1] START LR__C=49.88056698994767, LR__penalty=l2, PCA__n_components=0.7371077691077838
# [CV 4/5; 1/1] END LR__C=49.88056698994767, LR__penalty=l2, PCA__n_components=0.7371077691077838;, score=0.780 total time=  12.0s
# [CV 5/5; 1/1] START LR__C=49.88056698994767, LR__penalty=l2, PCA__n_components=0.7371077691077838
# [CV 5/5; 1/1] END LR__C=49.88056698994767, LR__penalty=l2, PCA__n_components=0.7371077691077838;, score=0.974 total time=  11.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=649.8643875352558, LR__penalty=l1, PCA__n_components=0.5883048557390346
# [CV 1/5; 1/1] END LR__C=649.8643875352558, LR__penalty=l1, PCA__n_components=0.5883048557390346;, score=0.923 total time=  11.4s
# [CV 2/5; 1/1] START LR__C=649.8643875352558, LR__penalty=l1, PCA__n_components=0.5883048557390346
# [CV 2/5; 1/1] END LR__C=649.8643875352558, LR__penalty=l1, PCA__n_components=0.5883048557390346;, score=0.865 total time=  11.8s
# [CV 3/5; 1/1] START LR__C=649.8643875352558, LR__penalty=l1, PCA__n_components=0.5883048557390346
# [CV 3/5; 1/1] END LR__C=649.8643875352558, LR__penalty=l1, PCA__n_components=0.5883048557390346;, score=0.865 total time=  11.4s
# [CV 4/5; 1/1] START LR__C=649.8643875352558, LR__penalty=l1, PCA__n_components=0.5883048557390346
# [CV 4/5; 1/1] END LR__C=649.8643875352558, LR__penalty=l1, PCA__n_components=0.5883048557390346;, score=0.905 total time=  11.5s
# [CV 5/5; 1/1] START LR__C=649.8643875352558, LR__penalty=l1, PCA__n_components=0.5883048557390346
# [CV 5/5; 1/1] END LR__C=649.8643875352558, LR__penalty=l1, PCA__n_components=0.5883048557390346;, score=0.900 total time=  11.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=3.992990497123127, LR__penalty=l2, PCA__n_components=0.8226013164233139
# [CV 1/5; 1/1] END LR__C=3.992990497123127, LR__penalty=l2, PCA__n_components=0.8226013164233139;, score=0.872 total time=  11.5s
# [CV 2/5; 1/1] START LR__C=3.992990497123127, LR__penalty=l2, PCA__n_components=0.8226013164233139
# [CV 2/5; 1/1] END LR__C=3.992990497123127, LR__penalty=l2, PCA__n_components=0.8226013164233139;, score=0.878 total time=  11.3s
# [CV 3/5; 1/1] START LR__C=3.992990497123127, LR__penalty=l2, PCA__n_components=0.8226013164233139
# [CV 3/5; 1/1] END LR__C=3.992990497123127, LR__penalty=l2, PCA__n_components=0.8226013164233139;, score=0.900 total time=  11.1s
# [CV 4/5; 1/1] START LR__C=3.992990497123127, LR__penalty=l2, PCA__n_components=0.8226013164233139
# [CV 4/5; 1/1] END LR__C=3.992990497123127, LR__penalty=l2, PCA__n_components=0.8226013164233139;, score=0.872 total time=  11.3s
# [CV 5/5; 1/1] START LR__C=3.992990497123127, LR__penalty=l2, PCA__n_components=0.8226013164233139
# [CV 5/5; 1/1] END LR__C=3.992990497123127, LR__penalty=l2, PCA__n_components=0.8226013164233139;, score=0.976 total time=  11.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=0.31757146963211025, LR__penalty=l1, PCA__n_components=0.6652441554854802
# [CV 1/5; 1/1] END LR__C=0.31757146963211025, LR__penalty=l1, PCA__n_components=0.6652441554854802;, score=0.947 total time=  11.4s
# [CV 2/5; 1/1] START LR__C=0.31757146963211025, LR__penalty=l1, PCA__n_components=0.6652441554854802
# [CV 2/5; 1/1] END LR__C=0.31757146963211025, LR__penalty=l1, PCA__n_components=0.6652441554854802;, score=0.950 total time=  20.8s
# [CV 3/5; 1/1] START LR__C=0.31757146963211025, LR__penalty=l1, PCA__n_components=0.6652441554854802
# [CV 3/5; 1/1] END LR__C=0.31757146963211025, LR__penalty=l1, PCA__n_components=0.6652441554854802;, score=0.833 total time=  11.5s
# [CV 4/5; 1/1] START LR__C=0.31757146963211025, LR__penalty=l1, PCA__n_components=0.6652441554854802
# [CV 4/5; 1/1] END LR__C=0.31757146963211025, LR__penalty=l1, PCA__n_components=0.6652441554854802;, score=0.829 total time=  11.5s
# [CV 5/5; 1/1] START LR__C=0.31757146963211025, LR__penalty=l1, PCA__n_components=0.6652441554854802
# [CV 5/5; 1/1] END LR__C=0.31757146963211025, LR__penalty=l1, PCA__n_components=0.6652441554854802;, score=0.950 total time=  11.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=2.6433700269494964, LR__penalty=l2, PCA__n_components=0.7428163514593766
# [CV 1/5; 1/1] END LR__C=2.6433700269494964, LR__penalty=l2, PCA__n_components=0.7428163514593766;, score=0.895 total time=  11.6s
# [CV 2/5; 1/1] START LR__C=2.6433700269494964, LR__penalty=l2, PCA__n_components=0.7428163514593766
# [CV 2/5; 1/1] END LR__C=2.6433700269494964, LR__penalty=l2, PCA__n_components=0.7428163514593766;, score=0.865 total time=  12.6s
# [CV 3/5; 1/1] START LR__C=2.6433700269494964, LR__penalty=l2, PCA__n_components=0.7428163514593766
# [CV 3/5; 1/1] END LR__C=2.6433700269494964, LR__penalty=l2, PCA__n_components=0.7428163514593766;, score=0.895 total time=  13.0s
# [CV 4/5; 1/1] START LR__C=2.6433700269494964, LR__penalty=l2, PCA__n_components=0.7428163514593766
# [CV 4/5; 1/1] END LR__C=2.6433700269494964, LR__penalty=l2, PCA__n_components=0.7428163514593766;, score=0.800 total time=  11.5s
# [CV 5/5; 1/1] START LR__C=2.6433700269494964, LR__penalty=l2, PCA__n_components=0.7428163514593766
# [CV 5/5; 1/1] END LR__C=2.6433700269494964, LR__penalty=l2, PCA__n_components=0.7428163514593766;, score=0.947 total time=  11.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START LR__C=0.5536794444975827, LR__penalty=l1, PCA__n_components=0.6606577586902106
# [CV 1/5; 1/1] END LR__C=0.5536794444975827, LR__penalty=l1, PCA__n_components=0.6606577586902106;, score=0.947 total time=  12.3s
# [CV 2/5; 1/1] START LR__C=0.5536794444975827, LR__penalty=l1, PCA__n_components=0.6606577586902106
# [CV 2/5; 1/1] END LR__C=0.5536794444975827, LR__penalty=l1, PCA__n_components=0.6606577586902106;, score=0.923 total time=  11.3s
# [CV 3/5; 1/1] START LR__C=0.5536794444975827, LR__penalty=l1, PCA__n_components=0.6606577586902106
# [CV 3/5; 1/1] END LR__C=0.5536794444975827, LR__penalty=l1, PCA__n_components=0.6606577586902106;, score=0.895 total time=  11.6s
# [CV 4/5; 1/1] START LR__C=0.5536794444975827, LR__penalty=l1, PCA__n_components=0.6606577586902106
# [CV 4/5; 1/1] END LR__C=0.5536794444975827, LR__penalty=l1, PCA__n_components=0.6606577586902106;, score=0.800 total time=  11.7s
# [CV 5/5; 1/1] START LR__C=0.5536794444975827, LR__penalty=l1, PCA__n_components=0.6606577586902106
# [CV 5/5; 1/1] END LR__C=0.5536794444975827, LR__penalty=l1, PCA__n_components=0.6606577586902106;, score=0.947 total time=  11.4s
# BayesSearchCV(estimator=Pipeline(steps=[('PCA', PCA(whiten=True)),
#                                         ('LR',
#                                          LogisticRegression(max_iter=5000,
#                                                             n_jobs=-1,
#                                                             solver='saga'))]),
#               scoring='f1',
#               search_spaces={'LR__C': Real(low=0.1, high=1000.0, prior='log-uniform', transform='normalize'),
#                              'LR__penalty': Categorical(categories=('l1', 'l2'), prior=None),
#                              'PCA__n_components': Real(low=0.5, high=0.95, prior='uniform', transform='normalize')},
#               verbose=10)

# %% [markdown]
# How does it perform on testing data?

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, bs.predict(X_test), digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.8969    0.8700    0.8832       100
#            1     0.8632    0.8913    0.8770        92
#
#     accuracy                         0.8802       192
#    macro avg     0.8800    0.8807    0.8801       192
# weighted avg     0.8807    0.8802    0.8803       192

# %% [markdown]
# Saving the final model for prediction:

# %%
jb.dump(bs, "bs_fitted.pkl")
# Out:
# ['bs_fitted.pkl']
